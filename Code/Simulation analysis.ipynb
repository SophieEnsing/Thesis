# %%
import pandas as pd
passengers = pd.read_csv("../../passengers.csv", index_col=0)
vehicles = pd.read_csv("../../vehicles.csv", index_col=0)

# %%
passengers.head(5)
# Out:
#                                        arrival  class_id  creation  \
# b6a95e1e-7167-11e9-8a58-7831c1d08f6a  06:09:45         0  05:30:00
# b6a96526-7167-11e9-93b1-7831c1d08f6a  06:17:15         0  05:30:13
# b6a96f6c-7167-11e9-967e-7831c1d08f6a  06:20:30         0  05:30:40
# b6a97c1e-7167-11e9-8afd-7831c1d08f6a  06:20:30         0  05:30:51
# b6a98812-7167-11e9-87a0-7831c1d08f6a  06:20:30         0  05:30:56
#
#                                             date departure      destination  \
# b6a95e1e-7167-11e9-8a58-7831c1d08f6a  2019-01-01  06:06:45       IJsbaanpad
# b6a96526-7167-11e9-93b1-7831c1d08f6a  2019-01-01  06:10:30  RoelofHartplein
# b6a96f6c-7167-11e9-967e-7831c1d08f6a  2019-01-01  06:04:30           DePijp
# b6a97c1e-7167-11e9-8afd-7831c1d08f6a  2019-01-01  06:10:30      Europaplein
# b6a98812-7167-11e9-87a0-7831c1d08f6a  2019-01-01  06:08:15            Noord
#
#                                                                 lines  \
# ...

# %%
vehicles.head(5)
# Out:
#                                        arrival        date departure     line  \
# 7308a4e2-7166-11e9-a3de-7831c1d08f6a  06:28:15  2019-01-01  05:30:00  metro52
# 730960a6-7166-11e9-a3af-7831c1d08f6a  06:31:21  2019-01-01  05:30:21  metro52
# 730986da-7166-11e9-b264-7831c1d08f6a  06:33:36  2019-01-01  05:30:27  metro52
# 730ac068-7166-11e9-a1bb-7831c1d08f6a  06:10:15  2019-01-01  05:30:53  metro52
# 730add9e-7166-11e9-8cd6-7831c1d08f6a  06:37:15  2019-01-01  05:31:19  metro52
#
#                                                                                   route
# 7308a4e2-7166-11e9-a3de-7831c1d08f6a  ['Noord', 'Noorderpark', 'CentraalStation', 'R...
# 730960a6-7166-11e9-a3af-7831c1d08f6a  ['Zuid', 'Europaplein', 'DePijp', 'Vijzelgrach...
# 730986da-7166-11e9-b264-7831c1d08f6a  ['Noord', 'Noorderpark', 'CentraalStation', 'R...
# 730ac068-7166-11e9-a1bb-7831c1d08f6a  ['Zuid', 'Europaplein', 'DePijp', 'Vijzelgrach...
# ...
