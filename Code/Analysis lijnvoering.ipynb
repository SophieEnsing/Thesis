# %%
import pandas as pd

# %%
routes = pd.read_csv('routes.txt', sep=",")
shapes = pd.read_csv('shapes.txt', sep=",")
stoptimes = pd.read_csv('stop_times.txt', sep=",")
stops = pd.read_csv('stops.txt', sep=",")
trips = pd.read_csv('trips.txt', sep=",")

# %%
GVBlijnen = routes["route_short_name"].tolist()
trips.head(5)
# Out:
#   route_id        service_id                  trip_id     trip_headsign  \
# 0   GVB:10  6118:GVB:10:D:WE   6118:GVB:10:D:WE:10:34        Azartplein
# 1   GVB:10  6118:GVB:10:D:WE  6118:GVB:10:D:WE:10:100        Azartplein
# 2   GVB:10  6118:GVB:10:D:WE  6118:GVB:10:D:WE:10:114  Westergasfabriek
# 3   GVB:10  6118:GVB:10:D:WE  6118:GVB:10:D:WE:10:242  Westergasfabriek
# 4   GVB:10  6118:GVB:10:D:WE  6118:GVB:10:D:WE:10:274  Westergasfabriek
#
#    trip_short_name trip_long_name  direction_id  block_id  shape_id  \
# 0               34            NaN             0       NaN  706213.0
# 1              100            NaN             0       NaN  706213.0
# 2              114            NaN             1       NaN  639615.0
# 3              242            NaN             1       NaN  639615.0
# 4              274            NaN             1       NaN  639615.0
#
#    wheelchair_accessible  bikes_allowed
# 0                      1            NaN
# 1                      1            NaN
# 2                      1            NaN
# 3                      1            NaN
# 4                      1            NaN
